# %% [markdown]
# # Questions

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(filename=r"C:\Users\9851a\Desktop\questions7.png")

# %%
month = int(input("Enter month number"))
match month:
    case month if month in (1, 3, 5, 7, 8, 10, 12):
        print("31 Days")
    case month if month in (4, 6, 9, 11):
        print("30 Days")
    case 2: # Feb month
        print("28 Days or 29 Days")
    case _: # Default case
        print("Invalid Month number")
# print()
# Out:
# 31 Days

# %%
print("""
1. Addition
2. Subtraction
3. Multiplication
4. Division

Please enter your choise accordingly
""")
choice = int(input())
match choice:
    case 1:
        print("Enter two numbers")
        a, b = int(input()), int(input())
        result = a + b
        print("Sum is", result)
    case 2:
        print("Enter two numbers")
        a, b = int(input()), int(input())
        result = a - b
        print("Subtraction is", result)
    case 3:
        print("Enter two numbers")
        a, b = int(input()), int(input())
        result = a * b
        print("Multiplication is", result)
    case 4:
        print("Enter two numbers")
        a, b = int(input()), int(input())
        result = a / b
        print("Difference is", result)
    case _:
        print("Please provide a valid responce")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
#
# Please enter your choise accordingly
#
# Please provide a valid responce
