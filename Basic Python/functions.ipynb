# %% [markdown]
# # Function

# %% [markdown]
# Function is a block of code which only runs when it is called.
#
# Function has a name for identification.

# %% [markdown]
# ### Function Defination

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(filename=r"C:\Users\9851a\Desktop\func1.png")

# %% [markdown]
# ### Function Call vs Function Definition

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(filename=r"C:\Users\9851a\Desktop\func2.png")

# %% [markdown]
# ### Ways to define a Function

# %% [markdown]
# 1. Takes Nothing, Returns Nothing
# 2. Takes Something, Returns Nothing
# 3. Takes Nothing, Return Something
# 4. Takes something, Return Something

# %%
# Takes Nothing, Returns Nothing
def add():
    print("Enter two numbers ")
    a = int(input())
    b = int(input())
    ans = a + b
    print("Sum is", ans)

add()
# Out:
# Enter two numbers
# Sum is 30

# %%
# Takes Something, Returns Nothing
def sub(a, b):
    ans = a - b
    print("Sub is", ans)

sub(10, 5)
# Out:
# Sub is 5

# %%
# Takes Nothing, Return Something
def add():
    print("Enter two numbers ")
    a = int(input())
    b = int(input())
    ans = a + b
    return ans

# print(add())
s = add()
print(s)
# Out:
# Enter two numbers
# 30

# %%
# Takes something, Return Something
def add(a, b):
    ans = a + b
    return ans

s = add(10, 20)
print(s)
# Out:
# 30

# %% [markdown]
# ### Default Arguments

# %% [markdown]
# Default value indicated that the function argument will take that value if no argument value is passed during the function call.
#
# The default value is assigned by using the assignment (=) operator.
#
# Note: You cannot have non default argument after default argument.

# %%
def add (a, b, c = 35, d = 40):
    ans = a + b + c + d
    return ans

print("Sum is", add(10, 20))
print("Sum is", add(10, 20, 100))
print("Sum is", add(100, 200, 300, 400))
# Out:
# Sum is 105
# Sum is 170
# Sum is 1000

# %% [markdown]
# ### Positional vs Keyword Arguments

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(filename=r"C:\Users\9851a\Desktop\func3.png")

# %%
def f1(a, b):
    print("a =", a, "b =", b)

f1(2, 5)
# Out:
# a = 2 b = 5

# %%
f1(b = 2, a = 3)
# Out:
# a = 3 b = 2

# %%
f1(b = 2, 3) # this is a compilation error
# Out:
#   Cell In[5], line 1
#     f1(b = 2, 3)
#                ^
# SyntaxError: positional argument follows keyword argument

# %%
f1(2, a = 3) # but this is a runtime error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 f1(2, a = 3)
#
# TypeError: f1() got multiple values for argument 'a'

# %% [markdown]
# ### Varaible length Arguments

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(filename=r"C:\Users\9851a\Desktop\func4.png")

# %%
def average(*t):
    ans = sum(t)/len(t)
    return ans

print("Average is ", average(10, 20))
print("Average is ", average(10, 20, 30, 40, 50, 60, 70))
# Out:
# Average is  15.0
# Average is  40.0
